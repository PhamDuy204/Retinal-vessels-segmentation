# %%
import torch 
import torchsummary

# %%
from dual_unet import SegModel
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from dual_unet import SegModel
#
# File ~/Documents/research-project/models/dual_unet/dual_unet.py:2
#       1 import torch.nn as nn
# ----> 2 from .modules import EncoderBlock, DecoderBlock
#       5 class SegModel(nn.Module):
#       6     """
#       7     Dual-Branch U-Net Architecture for Image Segmentation
#       8
#    (...)
#      23     - Flexible channel scaling throughout the network
#      24     """
#
# ImportError: attempted relative import with no known parent package
